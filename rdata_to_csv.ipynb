# %%
# !pip install pyreadr -q

# %%
import pandas as pd
import pyreadr

# %%
# Read the RData file
result = pyreadr.read_r( "NHFSPUF.rdata")

# %%
# Print the keys of the dictionary
print(result.keys())
# Out:
# odict_keys(['NHFSPUF'])

# %%
# Access the  object key and assign it to df
df = result['NHFSPUF']

# %%
# Convert DataFrame to CSV
df.to_csv("H1N1.csv", index=False)  # Set index=False if you don't want to include row numbers

# %%
df.head()
# Out:
#   INT_MONTH  LANGUAGE SAMP_DESIG SEQNUMHH SEQNUMP SUBGROUP VACC1_H1N1_M  \
# 0     OCT09         1         FR    38548  385481        A          NaN
# 1     OCT09         1         FR    18823  188231        A          NaN
# 2     OCT09         1         FR    18823  188232        C          NaN
# 3     NOV09         1         FR    54046  540461        A          NaN
# 4     OCT09         1         FR    21986  219861        A          NaN
#
#   VACC1_H1N1_T VACC1_H1N1_Y VACC1_SEAS_M  ... RACEETH4_I RACE_I_R RENT_OWN_R  \
# 0          NaN          NaN          NaN  ...          3        1          2
# 1          NaN          NaN           10  ...          4        3          2
# 2          NaN          NaN           10  ...          1        3          2
# 3          NaN          NaN           10  ...          3        1          1
# 4          NaN          NaN          NaN  ...          3        1          1
#
#   SEX_I CEN_REG         FLUWT HHS_REGION MSA3_I   MSA_DEF STATE
# ...
